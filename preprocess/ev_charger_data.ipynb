# %%
import requests
import json
import time
import csv
import pandas as pd
import numpy as np

# %%
import requests
import time
import json
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

API_KEY   = "iYO3sditsNW8LVE8oua33BnEPGcKevHL5KqhO8sgoEFxKRD4yyV+oRZfDpGlKbuzhAqzvlZk5ja2qHXKpfnDCg=="
BASE_URL  = "http://apis.data.go.kr/B552584/EvCharger/getChargerInfo"
ROWS      = 1000
DATA_TYPE = "JSON"

# --- 세션에 백오프+재시도 설정을 붙여둡니다 ---
def create_retry_session(
    retries: int = 3,
    backoff_factor: float = 0.3,
    status_forcelist: tuple = (500, 502, 504),
):
    session = requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
        raise_on_status=False,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount("http://", adapter)
    session.mount("https://", adapter)
    return session

def fetch_all_charger_info(max_overall_retries: int = 2):
    """
    전체 호출에 실패하면 max_overall_retries 만큼 재시도합니다.
    페이지별로는 세션 설정에 따라 자동 재시도되고, 
    그럼에도 에러가 나면 스킵합니다.
    """
    attempt = 0
    while attempt <= max_overall_retries:
        try:
            session = create_retry_session()
            all_data = []

            # 1) 총 건수 가져오기
            params = {
                "serviceKey": API_KEY,
                "numOfRows": ROWS,
                "pageNo": 1,
                "dataType": DATA_TYPE
            }
            resp = session.get(BASE_URL, params=params, timeout=10)
            resp.raise_for_status()
            result = resp.json()
            total_count = int(result.get("totalCount", 0))
            total_pages = (total_count // ROWS) + (1 if total_count % ROWS else 0)
            print(f"총 충전기 수: {total_count}건 → {total_pages}페이지")

            # 2) 페이지별 수집
            for page in range(1, total_pages + 1):
                print(f"[{page}/{total_pages}] 수집 중…", end=" ")
                params["pageNo"] = page
                try:
                    r = session.get(BASE_URL, params=params, timeout=10)
                    r.raise_for_status()
                    data = r.json()
                    items = data.get("items", {}).get("item", [])
                    if isinstance(items, dict):
                        all_data.append(items)
                    elif isinstance(items, list):
                        all_data.extend(items)
                    else:
                        print("→ 데이터 없음")
                        continue
                    print("완료")
                except Exception as e:
                    # 마지막 시도에도 실패하면 스킵
                    print(f"⚠️ 페이지 {page} 오류: {e} → 스킵")
                time.sleep(0.2)

            return all_data

        except Exception as e:
            attempt += 1
            print(f"❌ 전체 수집 실패 (시도 {attempt}/{max_overall_retries}): {e}")
            if attempt > max_overall_retries:
                print("💥 최대 재시도 횟수 초과, 종료합니다.")
                return []
            print("🔄 1초 후 다시 시도합니다…")
            time.sleep(1)

if __name__ == "__main__":
    chargers = fetch_all_charger_info()
    if chargers:
        with open("./02_interim_data/all_ev_chargers.json", "w", encoding="utf-8") as f:
            json.dump(chargers, f, ensure_ascii=False, indent=2)
        print(f"\n✅ 총 {len(chargers)}건 저장 완료: all_ev_chargers.json")
    else:
        print("❌ 데이터를 가져오지 못했습니다.")
# Out:
# 총 충전기 수: 445322건 → 446페이지
# [1/446] 수집 중… 완료
# [2/446] 수집 중… 완료
# [3/446] 수집 중… 완료
# [4/446] 수집 중… 완료
# [5/446] 수집 중… 완료
# [6/446] 수집 중… 완료
# [7/446] 수집 중… 완료
# [8/446] 수집 중… 완료
# [9/446] 수집 중… 완료
# [10/446] 수집 중… 완료
# [11/446] 수집 중… 완료
# [12/446] 수집 중… 완료
# [13/446] 수집 중… 완료
# [14/446] 수집 중… 완료
# [15/446] 수집 중… ⚠️ 페이지 15 오류: HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /B552584/EvCharger/getChargerInfo?serviceKey=iYO3sditsNW8LVE8oua33BnEPGcKevHL5KqhO8sgoEFxKRD4yyV%2BoRZfDpGlKbuzhAqzvlZk5ja2qHXKpfnDCg%3D%3D&numOfRows=1000&pageNo=15&dataType=JSON (Caused by ReadTimeoutError("HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)")) → 스킵
# [16/446] 수집 중… 완료
# [17/446] 수집 중… 완료
# [18/446] 수집 중… 완료
# [19/446] 수집 중… 완료
# [20/446] 수집 중… 완료
# [21/446] 수집 중… 완료
# [22/446] 수집 중… 완료
# [23/446] 수집 중… 완료
# [24/446] 수집 중… 완료
# [25/446] 수집 중… 완료
# [26/446] 수집 중… 완료
# [27/446] 수집 중… 완료
# [28/446] 수집 중… 완료
# [29/446] 수집 중… 완료
# [30/446] 수집 중… 완료
# [31/446] 수집 중… 완료
# [32/446] 수집 중… 완료
# [33/446] 수집 중… 완료
# [34/446] 수집 중… 완료
# [35/446] 수집 중… 완료
# [36/446] 수집 중… 완료
# [37/446] 수집 중… 완료
# [38/446] 수집 중… 완료
# [39/446] 수집 중… 완료
# [40/446] 수집 중… 완료
# [41/446] 수집 중… 완료
# [42/446] 수집 중… 완료
# [43/446] 수집 중… 완료
# [44/446] 수집 중… 완료
# [45/446] 수집 중… 완료
# [46/446] 수집 중… 완료
# [47/446] 수집 중… 완료
# [48/446] 수집 중… 완료
# [49/446] 수집 중… 완료
# [50/446] 수집 중… 완료
# [51/446] 수집 중… 완료
# [52/446] 수집 중… 완료
# [53/446] 수집 중… 완료
# [54/446] 수집 중… 완료
# [55/446] 수집 중… 완료
# [56/446] 수집 중… 완료
# [57/446] 수집 중… 완료
# [58/446] 수집 중… 완료
# [59/446] 수집 중… 완료
# [60/446] 수집 중… 완료
# [61/446] 수집 중… 완료
# [62/446] 수집 중… 완료
# [63/446] 수집 중… 완료
# [64/446] 수집 중… 완료
# [65/446] 수집 중… 완료
# [66/446] 수집 중… 완료
# [67/446] 수집 중… 완료
# [68/446] 수집 중… 완료
# [69/446] 수집 중… 완료
# [70/446] 수집 중… 완료
# [71/446] 수집 중… 완료
# [72/446] 수집 중… 완료
# [73/446] 수집 중… 완료
# [74/446] 수집 중… 완료
# [75/446] 수집 중… 완료
# [76/446] 수집 중… 완료
# [77/446] 수집 중… 완료
# [78/446] 수집 중… 완료
# [79/446] 수집 중… 완료
# [80/446] 수집 중… 완료
# [81/446] 수집 중… 완료
# [82/446] 수집 중… 완료
# [83/446] 수집 중… 완료
# [84/446] 수집 중… 완료
# [85/446] 수집 중… 완료
# [86/446] 수집 중… 완료
# [87/446] 수집 중… 완료
# [88/446] 수집 중… 완료
# [89/446] 수집 중… 완료
# [90/446] 수집 중… 완료
# [91/446] 수집 중… 완료
# [92/446] 수집 중… 완료
# [93/446] 수집 중… 완료
# [94/446] 수집 중… 완료
# [95/446] 수집 중… 완료
# [96/446] 수집 중… 완료
# [97/446] 수집 중… 완료
# [98/446] 수집 중… 완료
# [99/446] 수집 중… 완료
# [100/446] 수집 중… 완료
# [101/446] 수집 중… 완료
# [102/446] 수집 중… 완료
# [103/446] 수집 중… 완료
# [104/446] 수집 중… 완료
# [105/446] 수집 중… 완료
# [106/446] 수집 중… 완료
# [107/446] 수집 중… 완료
# [108/446] 수집 중… 완료
# [109/446] 수집 중… 완료
# [110/446] 수집 중… 완료
# [111/446] 수집 중… 완료
# [112/446] 수집 중… 완료
# [113/446] 수집 중… 완료
# [114/446] 수집 중… 완료
# [115/446] 수집 중… 완료
# [116/446] 수집 중… 완료
# [117/446] 수집 중… 완료
# [118/446] 수집 중… 완료
# [119/446] 수집 중… 완료
# [120/446] 수집 중… 완료
# [121/446] 수집 중… 완료
# [122/446] 수집 중… ⚠️ 페이지 122 오류: HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /B552584/EvCharger/getChargerInfo?serviceKey=iYO3sditsNW8LVE8oua33BnEPGcKevHL5KqhO8sgoEFxKRD4yyV%2BoRZfDpGlKbuzhAqzvlZk5ja2qHXKpfnDCg%3D%3D&numOfRows=1000&pageNo=122&dataType=JSON (Caused by ReadTimeoutError("HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)")) → 스킵
# [123/446] 수집 중… ⚠️ 페이지 123 오류: HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /B552584/EvCharger/getChargerInfo?serviceKey=iYO3sditsNW8LVE8oua33BnEPGcKevHL5KqhO8sgoEFxKRD4yyV%2BoRZfDpGlKbuzhAqzvlZk5ja2qHXKpfnDCg%3D%3D&numOfRows=1000&pageNo=123&dataType=JSON (Caused by ReadTimeoutError("HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)")) → 스킵
# [124/446] 수집 중… 완료
# [125/446] 수집 중… 완료
# [126/446] 수집 중… 완료
# [127/446] 수집 중… 완료
# [128/446] 수집 중… 완료
# [129/446] 수집 중… 완료
# [130/446] 수집 중… 완료
# [131/446] 수집 중… 완료
# [132/446] 수집 중… 완료
# [133/446] 수집 중… 완료
# [134/446] 수집 중… 완료
# [135/446] 수집 중… 완료
# [136/446] 수집 중… 완료
# [137/446] 수집 중… 완료
# [138/446] 수집 중… 완료
# [139/446] 수집 중… 완료
# [140/446] 수집 중… 완료
# [141/446] 수집 중… 완료
# [142/446] 수집 중… 완료
# [143/446] 수집 중… 완료
# [144/446] 수집 중… 완료
# [145/446] 수집 중… 완료
# [146/446] 수집 중… 완료
# [147/446] 수집 중… 완료
# [148/446] 수집 중… 완료
# [149/446] 수집 중… 완료
# [150/446] 수집 중… 완료
# [151/446] 수집 중… 완료
# [152/446] 수집 중… 완료
# [153/446] 수집 중… 완료
# [154/446] 수집 중… 완료
# [155/446] 수집 중… 완료
# [156/446] 수집 중… 완료
# [157/446] 수집 중… 완료
# [158/446] 수집 중… 완료
# [159/446] 수집 중… 완료
# [160/446] 수집 중… 완료
# [161/446] 수집 중… 완료
# [162/446] 수집 중… 완료
# [163/446] 수집 중… 완료
# [164/446] 수집 중… 완료
# [165/446] 수집 중… 완료
# [166/446] 수집 중… 완료
# [167/446] 수집 중… 완료
# [168/446] 수집 중… 완료
# [169/446] 수집 중… 완료
# [170/446] 수집 중… 완료
# [171/446] 수집 중… 완료
# [172/446] 수집 중… 완료
# [173/446] 수집 중… 완료
# [174/446] 수집 중… 완료
# [175/446] 수집 중… 완료
# [176/446] 수집 중… 완료
# [177/446] 수집 중… 완료
# [178/446] 수집 중… 완료
# [179/446] 수집 중… 완료
# [180/446] 수집 중… 완료
# [181/446] 수집 중… 완료
# [182/446] 수집 중… 완료
# [183/446] 수집 중… 완료
# [184/446] 수집 중… 완료
# [185/446] 수집 중… 완료
# [186/446] 수집 중… 완료
# [187/446] 수집 중… 완료
# [188/446] 수집 중… 완료
# [189/446] 수집 중… 완료
# [190/446] 수집 중… 완료
# [191/446] 수집 중… 완료
# [192/446] 수집 중… 완료
# [193/446] 수집 중… 완료
# [194/446] 수집 중… 완료
# [195/446] 수집 중… 완료
# [196/446] 수집 중… 완료
# [197/446] 수집 중… 완료
# [198/446] 수집 중… 완료
# [199/446] 수집 중… 완료
# [200/446] 수집 중… 완료
# [201/446] 수집 중… 완료
# [202/446] 수집 중… 완료
# [203/446] 수집 중… 완료
# [204/446] 수집 중… 완료
# [205/446] 수집 중… 완료
# [206/446] 수집 중… 완료
# [207/446] 수집 중… 완료
# [208/446] 수집 중… 완료
# [209/446] 수집 중… 완료
# [210/446] 수집 중… 완료
# [211/446] 수집 중… 완료
# [212/446] 수집 중… 완료
# [213/446] 수집 중… 완료
# [214/446] 수집 중… 완료
# [215/446] 수집 중… 완료
# [216/446] 수집 중… 완료
# [217/446] 수집 중… 완료
# [218/446] 수집 중… 완료
# [219/446] 수집 중… 완료
# [220/446] 수집 중… 완료
# [221/446] 수집 중… 완료
# [222/446] 수집 중… 완료
# [223/446] 수집 중… 완료
# [224/446] 수집 중… 완료
# [225/446] 수집 중… 완료
# [226/446] 수집 중… 완료
# [227/446] 수집 중… 완료
# [228/446] 수집 중… 완료
# [229/446] 수집 중… 완료
# [230/446] 수집 중… 완료
# [231/446] 수집 중… 완료
# [232/446] 수집 중… 완료
# [233/446] 수집 중… 완료
# [234/446] 수집 중… 완료
# [235/446] 수집 중… 완료
# [236/446] 수집 중… 완료
# [237/446] 수집 중… 완료
# [238/446] 수집 중… 완료
# [239/446] 수집 중… 완료
# [240/446] 수집 중… 완료
# [241/446] 수집 중… 완료
# [242/446] 수집 중… 완료
# [243/446] 수집 중… 완료
# [244/446] 수집 중… 완료
# [245/446] 수집 중… 완료
# [246/446] 수집 중… 완료
# [247/446] 수집 중… 완료
# [248/446] 수집 중… 완료
# [249/446] 수집 중… 완료
# [250/446] 수집 중… 완료
# [251/446] 수집 중… 완료
# [252/446] 수집 중… 완료
# [253/446] 수집 중… 완료
# [254/446] 수집 중… 완료
# [255/446] 수집 중… 완료
# [256/446] 수집 중… 완료
# [257/446] 수집 중… 완료
# [258/446] 수집 중… 완료
# [259/446] 수집 중… 완료
# [260/446] 수집 중… 완료
# [261/446] 수집 중… 완료
# [262/446] 수집 중… 완료
# [263/446] 수집 중… 완료
# [264/446] 수집 중… 완료
# [265/446] 수집 중… 완료
# [266/446] 수집 중… 완료
# [267/446] 수집 중… 완료
# [268/446] 수집 중… 완료
# [269/446] 수집 중… 완료
# [270/446] 수집 중… 완료
# [271/446] 수집 중… 완료
# [272/446] 수집 중… 완료
# [273/446] 수집 중… 완료
# [274/446] 수집 중… 완료
# [275/446] 수집 중… 완료
# [276/446] 수집 중… 완료
# [277/446] 수집 중… 완료
# [278/446] 수집 중… 완료
# [279/446] 수집 중… 완료
# [280/446] 수집 중… 완료
# [281/446] 수집 중… 완료
# [282/446] 수집 중… 완료
# [283/446] 수집 중… 완료
# [284/446] 수집 중… 완료
# [285/446] 수집 중… 완료
# [286/446] 수집 중… 완료
# [287/446] 수집 중… 완료
# [288/446] 수집 중… 완료
# [289/446] 수집 중… 완료
# [290/446] 수집 중… 완료
# [291/446] 수집 중… 완료
# [292/446] 수집 중… 완료
# [293/446] 수집 중… 완료
# [294/446] 수집 중… 완료
# [295/446] 수집 중… 완료
# [296/446] 수집 중… 완료
# [297/446] 수집 중… 완료
# [298/446] 수집 중… 완료
# [299/446] 수집 중… 완료
# [300/446] 수집 중… 완료
# [301/446] 수집 중… 완료
# [302/446] 수집 중… 완료
# [303/446] 수집 중… 완료
# [304/446] 수집 중… 완료
# [305/446] 수집 중… 완료
# [306/446] 수집 중… 완료
# [307/446] 수집 중… 완료
# [308/446] 수집 중… 완료
# [309/446] 수집 중… 완료
# [310/446] 수집 중… 완료
# [311/446] 수집 중… 완료
# [312/446] 수집 중… 완료
# [313/446] 수집 중… 완료
# [314/446] 수집 중… 완료
# [315/446] 수집 중… 완료
# [316/446] 수집 중… 완료
# [317/446] 수집 중… 완료
# [318/446] 수집 중… 완료
# [319/446] 수집 중… 완료
# [320/446] 수집 중… 완료
# [321/446] 수집 중… 완료
# [322/446] 수집 중… 완료
# [323/446] 수집 중… 완료
# [324/446] 수집 중… 완료
# [325/446] 수집 중… 완료
# [326/446] 수집 중… 완료
# [327/446] 수집 중… 완료
# [328/446] 수집 중… 완료
# [329/446] 수집 중… 완료
# [330/446] 수집 중… 완료
# [331/446] 수집 중… 완료
# [332/446] 수집 중… 완료
# [333/446] 수집 중… 완료
# [334/446] 수집 중… 완료
# [335/446] 수집 중… 완료
# [336/446] 수집 중… 완료
# [337/446] 수집 중… 완료
# [338/446] 수집 중… 완료
# [339/446] 수집 중… 완료
# [340/446] 수집 중… 완료
# [341/446] 수집 중… 완료
# [342/446] 수집 중… 완료
# [343/446] 수집 중… 완료
# [344/446] 수집 중… 완료
# [345/446] 수집 중… 완료
# [346/446] 수집 중… 완료
# [347/446] 수집 중… 완료
# [348/446] 수집 중… 완료
# [349/446] 수집 중… 완료
# [350/446] 수집 중… 완료
# [351/446] 수집 중… 완료
# [352/446] 수집 중… 완료
# [353/446] 수집 중… 완료
# [354/446] 수집 중… 완료
# [355/446] 수집 중… 완료
# [356/446] 수집 중… 완료
# [357/446] 수집 중… 완료
# [358/446] 수집 중… 완료
# [359/446] 수집 중… 완료
# [360/446] 수집 중… 완료
# [361/446] 수집 중… 완료
# [362/446] 수집 중… 완료
# [363/446] 수집 중… 완료
# [364/446] 수집 중… 완료
# [365/446] 수집 중… 완료
# [366/446] 수집 중… 완료
# [367/446] 수집 중… 완료
# [368/446] 수집 중… 완료
# [369/446] 수집 중… 완료
# [370/446] 수집 중… 완료
# [371/446] 수집 중… 완료
# [372/446] 수집 중… 완료
# [373/446] 수집 중… 완료
# [374/446] 수집 중… 완료
# [375/446] 수집 중… 완료
# [376/446] 수집 중… 완료
# [377/446] 수집 중… 완료
# [378/446] 수집 중… 완료
# [379/446] 수집 중… 완료
# [380/446] 수집 중… ⚠️ 페이지 380 오류: HTTPConnectionPool(host='apis.data.go.kr', port=80): Max retries exceeded with url: /B552584/EvCharger/getChargerInfo?serviceKey=iYO3sditsNW8LVE8oua33BnEPGcKevHL5KqhO8sgoEFxKRD4yyV%2BoRZfDpGlKbuzhAqzvlZk5ja2qHXKpfnDCg%3D%3D&numOfRows=1000&pageNo=380&dataType=JSON (Caused by ReadTimeoutError("HTTPConnectionPool(host='apis.data.go.kr', port=80): Read timed out. (read timeout=10)")) → 스킵
# [381/446] 수집 중… 완료
# [382/446] 수집 중… ⚠️ 페이지 382 오류: Expecting value: line 1 column 1 (char 0) → 스킵
# [383/446] 수집 중… 완료
# [384/446] 수집 중… 완료
# [385/446] 수집 중… 완료
# [386/446] 수집 중… 완료
# [387/446] 수집 중… 완료
# [388/446] 수집 중… 완료
# [389/446] 수집 중… 완료
# [390/446] 수집 중… 완료
# [391/446] 수집 중… 완료
# [392/446] 수집 중… 완료
# [393/446] 수집 중… 완료
# [394/446] 수집 중… 완료
# [395/446] 수집 중… 완료
# [396/446] 수집 중… 완료
# [397/446] 수집 중… 완료
# [398/446] 수집 중… 완료
# [399/446] 수집 중… 완료
# [400/446] 수집 중… 완료
# [401/446] 수집 중… 완료
# [402/446] 수집 중… 완료
# [403/446] 수집 중… 완료
# [404/446] 수집 중… 완료
# [405/446] 수집 중… 완료
# [406/446] 수집 중… 완료
# [407/446] 수집 중… 완료
# [408/446] 수집 중… 완료
# [409/446] 수집 중… 완료
# [410/446] 수집 중… 완료
# [411/446] 수집 중… 완료
# [412/446] 수집 중… 완료
# [413/446] 수집 중… 완료
# [414/446] 수집 중… 완료
# [415/446] 수집 중… 완료
# [416/446] 수집 중… 완료
# [417/446] 수집 중… 완료
# [418/446] 수집 중… 완료
# [419/446] 수집 중… 완료
# [420/446] 수집 중… 완료
# [421/446] 수집 중… 완료
# [422/446] 수집 중… 완료
# [423/446] 수집 중… 완료
# [424/446] 수집 중… 완료
# [425/446] 수집 중… 완료
# [426/446] 수집 중… 완료
# [427/446] 수집 중… 완료
# [428/446] 수집 중… 완료
# [429/446] 수집 중… 완료
# [430/446] 수집 중… 완료
# [431/446] 수집 중… 완료
# [432/446] 수집 중… 완료
# [433/446] 수집 중… 완료
# [434/446] 수집 중… 완료
# [435/446] 수집 중… 완료
# [436/446] 수집 중… 완료
# [437/446] 수집 중… 완료
# [438/446] 수집 중… 완료
# [439/446] 수집 중… 완료
# [440/446] 수집 중… 완료
# [441/446] 수집 중… 완료
# [442/446] 수집 중… 완료
# [443/446] 수집 중… 완료
# [444/446] 수집 중… 완료
# [445/446] 수집 중… 완료
# [446/446] 수집 중… 완료
#
# ✅ 총 440322건 저장 완료: all_ev_chargers.json

# %%
def json_to_csv(json_filepath="./02_interim_data/all_ev_chargers.json", csv_filepath="./02_interim_data/all_ev_chargers.csv"):
    # 1) JSON 파일 불러오기
    with open(json_filepath, "r", encoding="utf-8") as f:
        data = json.load(f)  # 리스트 of dict

    if not data:
        print("❌ 변환할 데이터가 없습니다.")
        return

    # 2) CSV 헤더(컬럼) 추출 — 모든 키들의 합집합
    #    (일부 항목이 빠진 충전소도 있어서, union 방식으로 헤더 생성)
    keys = set()
    for entry in data:
        keys.update(entry.keys())
    header = list(keys)

    # 3) CSV 파일 쓰기
    with open(csv_filepath, "w", encoding="utf-8", newline="") as f:
        writer = csv.DictWriter(f, fieldnames=header)
        writer.writeheader()
        for entry in data:
            writer.writerow(entry)

    print(f"✅ CSV 변환 완료: {csv_filepath}")

if __name__ == "__main__":
    json_to_csv()

# %%
import pandas as pd

df = pd.read_csv('./02_interim_data/all_ev_chargers.csv', dtype={'year': 'Int64', 'zcode': 'Int64'})

zcode_abbr = {
    11: '서울', 26: '부산', 27: '대구', 28: '인천', 29: '광주',
    30: '대전', 31: '울산', 36: '세종', 41: '경기', 51: '강원',
    43: '충북', 44: '충남', 52: '전북', 46: '전남', 47: '경북',
    48: '경남', 50: '제주'
}
df['sido'] = (
    df['zcode']
    .astype(str)          # 문자열로 변환
    .str[:2]              # 앞 두 글자만
    .astype(int)          # 정수로
    .map(zcode_abbr)      # 딕셔너리로 매핑
)

slow_types = {'02', '07', '08'}
df['charge_speed'] = df['chgerType'].astype(str).str.zfill(2).apply(
    lambda x: '완속' if x in slow_types else '급속'
)
region_yearly = (
    df.dropna(subset=['year', 'sido'])
      .groupby(['sido', 'year', 'charge_speed'])
      .size()
      .reset_index(name='count')
)

national = (
    region_yearly
    .groupby(['year', 'charge_speed'])['count']
    .sum()
    .reset_index()
    .assign(sido='전국')
)

combined = pd.concat([region_yearly, national], ignore_index=True)

combined = combined.sort_values(['sido', 'charge_speed', 'year'])
combined['cumulative_count'] = (
    combined
    .groupby(['sido', 'charge_speed'])['count']
    .cumsum()
)

pivot_df = (
    combined
    .pivot_table(
        index=['sido', 'year'],
        columns='charge_speed',
        values=['count', 'cumulative_count'],
        fill_value=0
    )
)

pivot_df.columns = [f"{speed}_{metric}" for metric, speed in pivot_df.columns]
pivot_df = pivot_df.reset_index()

pivot_df = pivot_df[[
    'sido', 'year',
    '급속_count', '급속_cumulative_count',
    '완속_count', '완속_cumulative_count'
]]

pivot_df.columns = [
    '시도', '연도',
    '급속 설치건수', '급속 누적건수',
    '완속 설치건수', '완속 누적건수'
]

pivot_df.to_csv('./02_interim_data/ev_charger_yearly_pivot.csv', index=False, encoding='utf-8-sig')
# Out:
# C:\Users\junjo\AppData\Local\Temp\ipykernel_67372\3406886271.py:3: DtypeWarning: Columns (5,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./02_interim_data/all_ev_chargers.csv', dtype={'year': 'Int64', 'zcode': 'Int64'})

# %%
# 연월 datetime 추가 (1월 기준)
pivot_df['연월'] = pd.to_datetime(pivot_df['연도'].astype(str) + '-01')

# 월 전체 범위 만들기
full_months = pd.date_range(
    start=pivot_df['연월'].min(),
    end=pivot_df['연월'].max() + pd.offsets.YearEnd(0),
    freq='MS'
)

# 시도별로 월 보간
interpolated_dfs = []

for sido, group in pivot_df.groupby('시도'):
    group = group.set_index('연월')

    # 연도만 있을 테니, 월 보간을 위해 전체 월 인덱스 추가
    group = group.reindex(full_months)
    group['시도'] = sido
    group.index.name = '연월'

    # 누적 건수 보간
    for col in ['급속 누적건수', '완속 누적건수']:
        group[col] = group[col].interpolate(method='linear', limit_direction='both')

    # 월별 설치 건수 = 누적건수.diff()
    group['급속 설치건수'] = group['급속 누적건수'].diff().fillna(group['급속 누적건수'])
    group['완속 설치건수'] = group['완속 누적건수'].diff().fillna(group['완속 누적건수'])

    # 정수로 변환
    for col in ['급속 설치건수', '급속 누적건수', '완속 설치건수', '완속 누적건수']:
        group[col] = group[col].round().astype('Int64')

    interpolated_dfs.append(group.reset_index())

# 합치기
monthly_df = pd.concat(interpolated_dfs, ignore_index=True)

# 연월 문자열로 변환
monthly_df['연월'] = monthly_df['연월'].dt.strftime('%Y-%m')

# 정렬
monthly_df = monthly_df.sort_values(['시도', '연월']).drop('연도', axis=1)

# 저장
monthly_df.to_csv('./02_interim_data/ev_charger_monthly_interpolated.csv', index=False, encoding='utf-8-sig')
