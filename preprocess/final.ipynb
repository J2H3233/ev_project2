# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df = pd.read_csv('test.csv')

X = df.select_dtypes(include=[np.number]).dropna()

vif_data = pd.DataFrame({
    'feature': X.columns,
    'VIF': [variance_inflation_factor(X.values, i) 
            for i in range(X.shape[1])]
})

pd.set_option('display.float_format', '{:,.2f}'.format)

vif_data
# Out:
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                feature               VIF
# 0                   년도         12,360.46
# 1                    월              9.74
# 2              전기차 등록수             14.44
# 3             전기차 순증가량              4.18
# 4                 주행거리            248.88
# 5              에너지소비효율            525.91
# 6                충전지용량            224.20
# 7          급속 충전기 설치건수             10.91
# 8          급속 충전기 누적건수             36.47
# 9          완속 충전기 설치건수             14.16
# 10         완속 충전기 누적건수             29.45
# 11           차량 등록수_총계               inf
# 12          차량 순증가량_총계               inf
# 13             수소차 등록수               inf
# 14            수소차 순증가량               inf
# 15          하이브리드차 등록수             55.76
# 16         하이브리드차 순증가량             30.85
# 17            평균기온(°C)         12,569.31
# 18          평균최고기온(°C)          4,773.10
# 19          평균최저기온(°C)          2,287.36
# 20  월합강수량(00~24h만)(mm)              4.42
# 21          미세먼지2.5 수치             61.60
# 22           미세먼지10 수치             39.50
# 23                 cpi         10,435.72
# 24                 실업률             22.88
# 25              평균기준금리             70.03
# 26                경상소득            279.75
# 27                  자산 12,259,479,898.60
# 28                  부채    359,201,958.99
# 29                순자산액  8,455,677,678.18
# 30                 보조금             20.29

# %%
def calculate_vif(X):
    """
    입력된 X(DataFrame)에 대해 각 컬럼의 VIF를 계산하여 DataFrame으로 리턴
    """
    vif_df = pd.DataFrame({
        'feature': X.columns,
        'VIF': [
            variance_inflation_factor(X.values, i)
            for i in range(X.shape[1])
        ]
    })
    return vif_df

def drop_high_vif(X, thresh=10.0, verbose=True):
    """
    VIF가 thresh보다 큰 변수가 없을 때까지,
    가장 VIF가 높은 변수를 하나씩 제거하는 반복문.
    """
    features = X.columns.tolist()
    while True:
        vif_df = calculate_vif(X[features])
        max_vif = vif_df['VIF'].max()
        if verbose:
            print(vif_df.sort_values('VIF', ascending=False).round(2))
        if max_vif <= thresh:
            if verbose:
                print(f"\n모든 VIF가 {thresh} 이하로 내려왔습니다 (최대 VIF = {max_vif:.2f})")
            break
        drop_feature = vif_df.sort_values('VIF', ascending=False)['feature'].iloc[0]
        if verbose:
            print(f"→ 제거: {drop_feature} (VIF={max_vif:.2f})\n")
        features.remove(drop_feature)
    return features, vif_df

if __name__ == "__main__":
    df = pd.read_csv('test.csv')
    df_numeric = df.select_dtypes(include=[np.number]).dropna()
    remaining_features, final_vif = drop_high_vif(df_numeric, thresh=10.0)
    print("최종 남은 변수:", remaining_features)
# Out:
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                feature               VIF
# 12          차량 순증가량_총계               inf
# 13             수소차 등록수               inf
# 14            수소차 순증가량               inf
# 11           차량 등록수_총계               inf
# 27                  자산 12,259,479,898.60
# 29                순자산액  8,455,677,678.18
# 28                  부채    359,201,958.99
# 17            평균기온(°C)         12,569.31
# 0                   년도         12,360.46
# 23                 cpi         10,435.72
# 18          평균최고기온(°C)          4,773.10
# 19          평균최저기온(°C)          2,287.36
# 5              에너지소비효율            525.91
# 26                경상소득            279.75
# 4                 주행거리            248.88
# 6                충전지용량            224.20
# 25              평균기준금리             70.03
# 21          미세먼지2.5 수치             61.60
# 15          하이브리드차 등록수             55.76
# 22           미세먼지10 수치             39.50
# 8          급속 충전기 누적건수             36.47
# 16         하이브리드차 순증가량             30.85
# 10         완속 충전기 누적건수             29.45
# 24                 실업률             22.88
# 30                 보조금             20.29
# 2              전기차 등록수             14.44
# 9          완속 충전기 설치건수             14.16
# 7          급속 충전기 설치건수             10.91
# 1                    월              9.74
# 20  월합강수량(00~24h만)(mm)              4.42
# 3             전기차 순증가량              4.18
# → 제거: 차량 순증가량_총계 (VIF=inf)
#
#                feature               VIF
# 11           차량 등록수_총계               inf
# 12             수소차 등록수               inf
# 26                  자산 12,259,479,898.60
# 28                순자산액  8,455,677,678.18
# 27                  부채    359,201,958.99
# 16            평균기온(°C)         12,569.31
# 0                   년도         12,360.46
# 22                 cpi         10,435.72
# 17          평균최고기온(°C)          4,773.10
# 18          평균최저기온(°C)          2,287.36
# 5              에너지소비효율            525.91
# 25                경상소득            279.75
# 4                 주행거리            248.88
# 6                충전지용량            224.20
# 24              평균기준금리             70.03
# 20          미세먼지2.5 수치             61.60
# 14          하이브리드차 등록수             55.76
# 21           미세먼지10 수치             39.50
# 8          급속 충전기 누적건수             36.47
# 15         하이브리드차 순증가량             30.85
# 10         완속 충전기 누적건수             29.45
# 23                 실업률             22.88
# 29                 보조금             20.29
# 2              전기차 등록수             14.44
# 9          완속 충전기 설치건수             14.16
# 7          급속 충전기 설치건수             10.91
# 1                    월              9.74
# 19  월합강수량(00~24h만)(mm)              4.42
# 13            수소차 순증가량              4.31
# 3             전기차 순증가량              4.18
# → 제거: 차량 등록수_총계 (VIF=inf)
#
#                feature               VIF
# 25                  자산 12,259,479,898.60
# 27                순자산액  8,455,677,678.18
# 26                  부채    359,201,958.99
# 15            평균기온(°C)         12,569.31
# 0                   년도         12,360.46
# 21                 cpi         10,435.72
# 16          평균최고기온(°C)          4,773.10
# 17          평균최저기온(°C)          2,287.36
# 5              에너지소비효율            525.91
# 24                경상소득            279.75
# 4                 주행거리            248.88
# 6                충전지용량            224.20
# 23              평균기준금리             70.03
# 19          미세먼지2.5 수치             61.60
# 13          하이브리드차 등록수             55.76
# 20           미세먼지10 수치             39.50
# 8          급속 충전기 누적건수             36.47
# 14         하이브리드차 순증가량             30.85
# 10         완속 충전기 누적건수             29.45
# 22                 실업률             22.88
# 28                 보조금             20.29
# 11             수소차 등록수             20.15
# 2              전기차 등록수             14.44
# 9          완속 충전기 설치건수             14.16
# 7          급속 충전기 설치건수             10.91
# 1                    월              9.74
# 18  월합강수량(00~24h만)(mm)              4.42
# 12            수소차 순증가량              4.31
# 3             전기차 순증가량              4.18
# → 제거: 자산 (VIF=12259479898.60)
#
#                feature       VIF
# 15            평균기온(°C) 12,535.28
# 0                   년도 12,358.49
# 21                 cpi 10,432.34
# 16          평균최고기온(°C)  4,735.01
# 17          평균최저기온(°C)  2,286.92
# 5              에너지소비효율    525.17
# 24                경상소득    276.99
# 4                 주행거리    248.58
# 6                충전지용량    224.03
# 25                  부채     88.69
# 26                순자산액     70.12
# 23              평균기준금리     70.03
# 19          미세먼지2.5 수치     61.58
# 13          하이브리드차 등록수     55.76
# 20           미세먼지10 수치     39.48
# 8          급속 충전기 누적건수     35.01
# 14         하이브리드차 순증가량     30.85
# 10         완속 충전기 누적건수     28.15
# 22                 실업률     22.87
# 27                 보조금     20.28
# 11             수소차 등록수     20.03
# 2              전기차 등록수     14.40
# 9          완속 충전기 설치건수     13.91
# 7          급속 충전기 설치건수     10.21
# 1                    월      9.74
# 18  월합강수량(00~24h만)(mm)      4.39
# 12            수소차 순증가량      4.31
# 3             전기차 순증가량      4.18
# → 제거: 평균기온(°C) (VIF=12535.28)
#
#                feature       VIF
# 0                   년도 12,208.58
# 20                 cpi 10,336.65
# 5              에너지소비효율    521.81
# 23                경상소득    276.67
# 4                 주행거리    247.51
# 6                충전지용량    222.96
# 15          평균최고기온(°C)    209.24
# 24                  부채     88.69
# 16          평균최저기온(°C)     86.59
# 25                순자산액     70.08
# 22              평균기준금리     69.51
# 18          미세먼지2.5 수치     57.79
# 13          하이브리드차 등록수     55.75
# 19           미세먼지10 수치     35.22
# 8          급속 충전기 누적건수     34.86
# 14         하이브리드차 순증가량     30.85
# 10         완속 충전기 누적건수     27.91
# 21                 실업률     22.86
# 11             수소차 등록수     20.02
# 26                 보조금     19.79
# 2              전기차 등록수     14.34
# 9          완속 충전기 설치건수     13.89
# 7          급속 충전기 설치건수     10.17
# 1                    월      9.07
# 17  월합강수량(00~24h만)(mm)      4.36
# 12            수소차 순증가량      4.31
# 3             전기차 순증가량      4.18
# → 제거: 년도 (VIF=12208.58)
#
#                feature    VIF
# 19                 cpi 403.46
# 22                경상소득 274.23
# 4              에너지소비효율 257.14
# 14          평균최고기온(°C) 209.21
# 3                 주행거리 123.04
# 5                충전지용량  89.85
# 23                  부채  88.60
# 15          평균최저기온(°C)  86.50
# 24                순자산액  68.91
# 17          미세먼지2.5 수치  55.97
# 12          하이브리드차 등록수  55.69
# 18           미세먼지10 수치  35.20
# 7          급속 충전기 누적건수  33.79
# 13         하이브리드차 순증가량  30.83
# 9          완속 충전기 누적건수  27.58
# 20                 실업률  22.85
# 10             수소차 등록수  19.93
# 25                 보조금  19.79
# 1              전기차 등록수  14.34
# 8          완속 충전기 설치건수  13.85
# 21              평균기준금리  10.46
# 6          급속 충전기 설치건수  10.16
# 0                    월   8.97
# 16  월합강수량(00~24h만)(mm)   4.34
# 11            수소차 순증가량   4.31
# 2             전기차 순증가량   4.17
# → 제거: cpi (VIF=403.46)
#
#                feature    VIF
# 4              에너지소비효율 198.42
# 14          평균최고기온(°C) 194.65
# 21                경상소득 192.39
# 3                 주행거리 101.27
# 15          평균최저기온(°C)  82.67
# 22                  부채  82.19
# 5                충전지용량  76.60
# 23                순자산액  68.57
# 12          하이브리드차 등록수  55.47
# 17          미세먼지2.5 수치  54.49
# 18           미세먼지10 수치  34.57
# 7          급속 충전기 누적건수  33.41
# 13         하이브리드차 순증가량  30.66
# 9          완속 충전기 누적건수  26.93
# 19                 실업률  21.38
# 10             수소차 등록수  19.84
# 24                 보조금  19.60
# 1              전기차 등록수  14.13
# 8          완속 충전기 설치건수  13.74
# 6          급속 충전기 설치건수  10.16
# 0                    월   8.41
# 20              평균기준금리   8.09
# 16  월합강수량(00~24h만)(mm)   4.34
# 11            수소차 순증가량   4.30
# 2             전기차 순증가량   4.17
# → 제거: 에너지소비효율 (VIF=198.42)
#
#                feature    VIF
# 13          평균최고기온(°C) 188.11
# 20                경상소득 180.87
# 14          평균최저기온(°C)  81.98
# 21                  부채  81.85
# 22                순자산액  68.45
# 4                충전지용량  56.22
# 11          하이브리드차 등록수  54.98
# 16          미세먼지2.5 수치  50.16
# 17           미세먼지10 수치  34.57
# 6          급속 충전기 누적건수  33.36
# 12         하이브리드차 순증가량  30.61
# 8          완속 충전기 누적건수  26.75
# 9              수소차 등록수  19.63
# 23                 보조금  19.56
# 18                 실업률  17.80
# 3                 주행거리  14.41
# 1              전기차 등록수  14.08
# 7          완속 충전기 설치건수  13.06
# 5          급속 충전기 설치건수   9.44
# 19              평균기준금리   8.01
# 0                    월   7.98
# 10            수소차 순증가량   4.30
# 15  월합강수량(00~24h만)(mm)   4.22
# 2             전기차 순증가량   4.14
# → 제거: 평균최고기온(°C) (VIF=188.11)
#
#                feature    VIF
# 19                경상소득 156.77
# 20                  부채  81.80
# 21                순자산액  64.95
# 4                충전지용량  56.21
# 11          하이브리드차 등록수  54.95
# 15          미세먼지2.5 수치  49.99
# 6          급속 충전기 누적건수  32.88
# 16           미세먼지10 수치  31.83
# 12         하이브리드차 순증가량  30.44
# 8          완속 충전기 누적건수  26.56
# 9              수소차 등록수  19.54
# 22                 보조금  18.00
# 17                 실업률  17.68
# 1              전기차 등록수  14.03
# 3                 주행거리  13.96
# 7          완속 충전기 설치건수  12.96
# 5          급속 충전기 설치건수   9.23
# 18              평균기준금리   8.00
# 0                    월   7.96
# 13          평균최저기온(°C)   7.24
# 10            수소차 순증가량   4.30
# 2             전기차 순증가량   4.14
# 14  월합강수량(00~24h만)(mm)   3.70
# → 제거: 경상소득 (VIF=156.77)
#
#                feature   VIF
# 19                  부채 71.63
# 20                순자산액 56.91
# 11          하이브리드차 등록수 54.69
# 4                충전지용량 54.55
# 15          미세먼지2.5 수치 47.13
# 16           미세먼지10 수치 31.83
# 6          급속 충전기 누적건수 30.43
# 12         하이브리드차 순증가량 30.43
# 8          완속 충전기 누적건수 25.40
# 9              수소차 등록수 19.44
# 21                 보조금 17.83
# 17                 실업률 16.83
# 3                 주행거리 13.71
# 1              전기차 등록수 13.58
# 7          완속 충전기 설치건수 12.80
# 5          급속 충전기 설치건수  9.22
# 0                    월  7.71
# 13          평균최저기온(°C)  6.95
# 18              평균기준금리  6.01
# 10            수소차 순증가량  4.29
# 2             전기차 순증가량  4.14
# 14  월합강수량(00~24h만)(mm)  3.70
# → 제거: 부채 (VIF=71.63)
#
#                feature   VIF
# 11          하이브리드차 등록수 54.69
# 4                충전지용량 52.92
# 15          미세먼지2.5 수치 46.35
# 16           미세먼지10 수치 31.72
# 12         하이브리드차 순증가량 30.39
# 6          급속 충전기 누적건수 25.32
# 8          완속 충전기 누적건수 20.80
# 9              수소차 등록수 19.41
# 20                 보조금 17.56
# 17                 실업률 16.82
# 19                순자산액 16.16
# 3                 주행거리 13.62
# 1              전기차 등록수 13.16
# 7          완속 충전기 설치건수 12.52
# 5          급속 충전기 설치건수  9.17
# 0                    월  7.49
# 13          평균최저기온(°C)  6.89
# 18              평균기준금리  6.01
# 10            수소차 순증가량  4.28
# 2             전기차 순증가량  4.13
# 14  월합강수량(00~24h만)(mm)  3.70
# → 제거: 하이브리드차 등록수 (VIF=54.69)
#
#                feature   VIF
# 4                충전지용량 52.30
# 14          미세먼지2.5 수치 46.33
# 15           미세먼지10 수치 31.65
# 6          급속 충전기 누적건수 23.98
# 8          완속 충전기 누적건수 20.23
# 19                 보조금 17.54
# 16                 실업률 16.57
# 18                순자산액 16.16
# 3                 주행거리 13.54
# 7          완속 충전기 설치건수 12.46
# 11         하이브리드차 순증가량 11.92
# 1              전기차 등록수 11.58
# 9              수소차 등록수 11.22
# 5          급속 충전기 설치건수  9.16
# 0                    월  7.46
# 12          평균최저기온(°C)  6.89
# 17              평균기준금리  6.00
# 2             전기차 순증가량  4.03
# 13  월합강수량(00~24h만)(mm)  3.70
# 10            수소차 순증가량  3.58
# → 제거: 충전지용량 (VIF=52.30)
#
#                feature   VIF
# 13          미세먼지2.5 수치 42.82
# 14           미세먼지10 수치 30.94
# 5          급속 충전기 누적건수 23.75
# 7          완속 충전기 누적건수 20.16
# 17                순자산액 15.53
# 18                 보조금 15.18
# 15                 실업률 13.42
# 6          완속 충전기 설치건수 12.16
# 10         하이브리드차 순증가량 11.91
# 1              전기차 등록수 11.56
# 8              수소차 등록수 11.16
# 3                 주행거리 10.67
# 4          급속 충전기 설치건수  9.12
# 0                    월  7.39
# 11          평균최저기온(°C)  6.78
# 16              평균기준금리  5.73
# 2             전기차 순증가량  4.02
# 9             수소차 순증가량  3.58
# 12  월합강수량(00~24h만)(mm)  3.56
# → 제거: 미세먼지2.5 수치 (VIF=42.82)
#
#                feature   VIF
# 5          급속 충전기 누적건수 23.70
# 7          완속 충전기 누적건수 20.14
# 13           미세먼지10 수치 15.67
# 16                순자산액 15.07
# 17                 보조금 14.75
# 14                 실업률 12.25
# 6          완속 충전기 설치건수 12.16
# 10         하이브리드차 순증가량 11.89
# 1              전기차 등록수 11.56
# 8              수소차 등록수 11.12
# 3                 주행거리 10.35
# 4          급속 충전기 설치건수  9.09
# 0                    월  7.37
# 15              평균기준금리  5.64
# 11          평균최저기온(°C)  5.53
# 2             전기차 순증가량  4.00
# 9             수소차 순증가량  3.58
# 12  월합강수량(00~24h만)(mm)  3.53
# → 제거: 급속 충전기 누적건수 (VIF=23.70)
#
#                feature   VIF
# 12           미세먼지10 수치 15.55
# 15                순자산액 14.24
# 16                 보조금 14.10
# 13                 실업률 12.23
# 5          완속 충전기 설치건수 11.77
# 9          하이브리드차 순증가량 11.59
# 1              전기차 등록수 11.22
# 7              수소차 등록수 11.11
# 3                 주행거리 10.24
# 4          급속 충전기 설치건수  8.26
# 0                    월  7.37
# 6          완속 충전기 누적건수  6.13
# 10          평균최저기온(°C)  5.52
# 14              평균기준금리  5.20
# 2             전기차 순증가량  3.98
# 11  월합강수량(00~24h만)(mm)  3.53
# 8             수소차 순증가량  3.51
# → 제거: 미세먼지10 수치 (VIF=15.55)
#
#                feature   VIF
# 14                순자산액 12.38
# 5          완속 충전기 설치건수 11.69
# 9          하이브리드차 순증가량 11.59
# 1              전기차 등록수 11.20
# 7              수소차 등록수 11.11
# 12                 실업률 10.98
# 15                 보조금 10.69
# 3                 주행거리  9.61
# 4          급속 충전기 설치건수  8.25
# 0                    월  6.45
# 6          완속 충전기 누적건수  6.06
# 13              평균기준금리  4.84
# 10          평균최저기온(°C)  4.63
# 2             전기차 순증가량  3.95
# 8             수소차 순증가량  3.51
# 11  월합강수량(00~24h만)(mm)  3.50
# → 제거: 순자산액 (VIF=12.38)
#
#                feature   VIF
# 9          하이브리드차 순증가량 11.46
# 5          완속 충전기 설치건수 11.20
# 7              수소차 등록수 11.11
# 1              전기차 등록수 11.03
# 14                 보조금 10.68
# 3                 주행거리  9.28
# 12                 실업률  8.89
# 4          급속 충전기 설치건수  8.19
# 0                    월  6.24
# 6          완속 충전기 누적건수  6.05
# 13              평균기준금리  4.61
# 10          평균최저기온(°C)  4.58
# 2             전기차 순증가량  3.94
# 8             수소차 순증가량  3.51
# 11  월합강수량(00~24h만)(mm)  3.50
# → 제거: 하이브리드차 순증가량 (VIF=11.46)
#
#                feature   VIF
# 5          완속 충전기 설치건수 11.19
# 13                 보조금 10.66
# 3                 주행거리  9.23
# 7              수소차 등록수  9.11
# 11                 실업률  8.85
# 1              전기차 등록수  8.27
# 4          급속 충전기 설치건수  7.97
# 0                    월  6.24
# 6          완속 충전기 누적건수  6.04
# 12              평균기준금리  4.60
# 9           평균최저기온(°C)  4.57
# 2             전기차 순증가량  3.88
# 10  월합강수량(00~24h만)(mm)  3.50
# 8             수소차 순증가량  3.22
# → 제거: 완속 충전기 설치건수 (VIF=11.19)
#
#                feature   VIF
# 12                 보조금 10.45
# 3                 주행거리  9.18
# 6              수소차 등록수  8.82
# 10                 실업률  8.47
# 1              전기차 등록수  7.91
# 0                    월  6.21
# 8           평균최저기온(°C)  4.51
# 11              평균기준금리  4.48
# 5          완속 충전기 누적건수  4.30
# 2             전기차 순증가량  3.83
# 9   월합강수량(00~24h만)(mm)  3.48
# 4          급속 충전기 설치건수  3.36
# 7             수소차 순증가량  3.20
# → 제거: 보조금 (VIF=10.45)
#
#                feature  VIF
# 3                 주행거리 9.01
# 6              수소차 등록수 8.80
# 1              전기차 등록수 7.87
# 10                 실업률 5.51
# 11              평균기준금리 4.48
# 5          완속 충전기 누적건수 4.24
# 0                    월 4.16
# 8           평균최저기온(°C) 4.15
# 2             전기차 순증가량 3.81
# 9   월합강수량(00~24h만)(mm) 3.48
# 4          급속 충전기 설치건수 3.24
# 7             수소차 순증가량 3.20
#
# 모든 VIF가 10.0 이하로 내려왔습니다 (최대 VIF = 9.01)
# 최종 남은 변수: ['월', '전기차 등록수', '전기차 순증가량', '주행거리', '급속 충전기 설치건수', '완속 충전기 누적건수', '수소차 등록수', '수소차 순증가량', '평균최저기온(°C)', '월합강수량(00~24h만)(mm)', '실업률', '평균기준금리']

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
import random

def compute_max_vif(X):
    """DataFrame X의 변수들에 대해 max VIF를 계산."""
    vifs = [
        variance_inflation_factor(X.values, i)
        for i in range(X.shape[1])
    ]
    return max(vifs)

def random_feature_search(df, n_iter=1000, thresh=10.0, random_state=None):
    """
    무작위로 변수 하나를 제거해가며 최적 조합을 찾는 단순 Random Search
    - df: VIF 계산 대상 DataFrame (수치형 변수만)
    - n_iter: 반복 횟수
    - thresh: 이상적 max VIF 임계값
    """
    if random_state is not None:
        random.seed(random_state)
        np.random.seed(random_state)

    features = list(df.columns)
    best_subset = features.copy()
    best_score = -np.inf
    best_vif  = None

    for it in range(n_iter):
        # 현재 후보 집합: best_subset 에서 랜덤하게 하나를 빼 본다
        cand = best_subset.copy()
        drop = random.choice(cand)
        cand.remove(drop)

        X_cand = df[cand].dropna()
        max_vif = compute_max_vif(X_cand)

        # 점수 계산: (남긴 변수 개수) - alpha * max_vif
        # alpha 를 조정해가며 '개수 우선' vs 'VIF 우선' 가중치를 바꿀 수 있음
        alpha = 0.1
        score = len(cand) - alpha * max_vif

        # 임계치 이하여서 score가 개선되면 갱신
        if max_vif <= thresh and score > best_score:
            best_score  = score
            best_subset = cand
            best_vif    = max_vif

    return best_subset, best_vif

# 사용 예시
if __name__ == "__main__":
    df = pd.read_csv('test.csv')
    # 수치형 변수만 추리기
    X = df.select_dtypes(include=[np.number]).dropna()

    best_feats, best_max_vif = random_feature_search(
        X, n_iter=2000, thresh=10.0, random_state=42
    )

    print("최적 변수 조합 (개수={}):".format(len(best_feats)), best_feats)
    print("해당 조합의 최대 VIF:", best_max_vif)
# Out:
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\Users\junjo\anaconda3\envs\ev_project2\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
